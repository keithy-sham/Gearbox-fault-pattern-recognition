# %%
import numpy as np
import pandas as pd
from nptdms import TdmsFile as td
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'#将图片保存为矢量图

plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文
plt.rcParams['axes.unicode_minus']=False  #用来正常显示负号

# %%
path = 'C:/Users/shamrockyj/Desktop/毕设：航空发动机智能运维与健康管理/毕业论文/故障数据/'

# %% [markdown]
# ### 平行齿轮箱二级主动轮

# %%
filename1 = "C:/Users/shamrockyj/Desktop/DDS数据/36T/34_22_normal_36T_1_22-02-18_1010.tdms"
tf1 = td.read(filename1)
filename2 = "C:/Users/shamrockyj/Desktop/DDS数据/36T/34_22_chip_36T_1_22-02-21_1113.tdms"
tf2 = td.read(filename2)
filename3 = "C:/Users/shamrockyj/Desktop/DDS数据/36T/34_22_crack_36T_1_22-02-22_0950.tdms"
tf3 = td.read(filename3)
filename4 = "C:/Users/shamrockyj/Desktop/DDS数据/36T/34_22_eccentric_36T_1_22-02-23_1441.tdms"
tf4 = td.read(filename4)
filename5 = "C:/Users/shamrockyj/Desktop/DDS数据/36T/34_22_miss_36T_1_22-02-18_1529.tdms"
tf5 = td.read(filename5)
filename6 = "C:/Users/shamrockyj/Desktop/DDS数据/36T/34_22_worn_36T_1_22-02-23_1000.tdms"
tf6 = td.read(filename6)

# %%
f = 51200

# %%
df1 = tf1.as_dataframe()
df2 = tf2.as_dataframe()
df3 = tf3.as_dataframe()
df4 = tf4.as_dataframe()
df5 = tf5.as_dataframe()
df6 = tf6.as_dataframe()

# %%
plt.figure(figsize=(12,6))
plt.subplot(6,1,1)
plt.plot(df1.iloc[:f//10,4],label = '正常',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(6,1,2)
plt.plot(df2.iloc[:f//10,4],label = '断齿',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(6,1,3)
plt.plot(df3.iloc[:f//10,4],label = '裂纹',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(6,1,4)
plt.plot(df4.iloc[:f//10,4],label = '偏心',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(6,1,5)
plt.plot(df5.iloc[:f//10,4],label = '缺齿',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(6,1,6)
plt.plot(df6.iloc[:f//10,4],label = '磨损',linewidth=1)
plt.legend(loc = 'upper right')

# %% [markdown]
# ### 平行齿轮箱轴承

# %%
filename7 = "C:/Users/shamrockyj/Desktop/DDS数据/平行中间轴轴承/34_22_ball_bear_output_1_22-03-18_0940.tdms"
tf7 = td.read(filename7)
filename8 = "C:/Users/shamrockyj/Desktop/DDS数据/平行中间轴轴承/34_22_combination_bear_output_1_22-03-21_0942.tdms"
tf8 = td.read(filename8)
filename9 = "C:/Users/shamrockyj/Desktop/DDS数据/平行中间轴轴承/34_22_inner_bear_output_1_22-03-15_1433.tdms"
tf9 = td.read(filename9)
filename10 = "C:/Users/shamrockyj/Desktop/DDS数据/平行中间轴轴承/34_22_outer_bear_output_1_22-03-16_1339.tdms"
tf10 = td.read(filename10)

# %%
df7 = tf7.as_dataframe()
df8 = tf8.as_dataframe()
df9 = tf9.as_dataframe()
df10 = tf10.as_dataframe()

# %%
plt.figure(figsize=(12,6))
plt.subplot(5,1,1)
plt.plot(df1.iloc[:f//10,2],label = '正常',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(5,1,2)
plt.plot(df7.iloc[:f//10,2],label = '滚动体',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(5,1,3)
plt.plot(df8.iloc[:f//10,2],label = '联合故障',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(5,1,4)
plt.plot(df9.iloc[:f//10,2],label = '内圈故障',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(5,1,5)
plt.plot(df10.iloc[:f//10,2],label = '外圈故障',linewidth=1)
plt.legend(loc = 'upper right')

# %%
import seaborn as sns
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
ax1 = sns.kdeplot(df1.iloc[:f//10,2],shade=True,color='#c0504d',linewidth=0.7,label='正常')
ax1 = sns.kdeplot(df2.iloc[:f//10,2],shade=True,color= '#4bacc6',linewidth=0.7,label='断齿')
ax1 = sns.kdeplot(df3.iloc[:f//10,2],shade=True,color='#8064a2',linewidth=0.7,label='裂纹')
ax1 = sns.kdeplot(df4.iloc[:f//10,2],shade=True,color='b',linewidth=0.7,label='偏心')
ax1 = sns.kdeplot(df5.iloc[:f//10,2],shade=True,color= 'r',linewidth=0.7,label='缺齿')
ax1 = sns.kdeplot(df6.iloc[:f//10,2],shade=True,color='g',linewidth=0.7,label='磨损')
plt.subplot(1,2,2)
ax1 = sns.kdeplot(df1.iloc[:f//10,2],shade=True,color='#c0504d',linewidth=0.7,label='正常')
ax1 = sns.kdeplot(df7.iloc[:f//10,2],shade=True,color='#4bacc6',linewidth=0.7,label='滚动体')
ax1 = sns.kdeplot(df8.iloc[:f//10,2],shade=True,color= '#8064a2',linewidth=0.7,label='联合')
ax1 = sns.kdeplot(df9.iloc[:f//10,2],shade=True,color='b',linewidth=0.7,label='内圈')
ax1 = sns.kdeplot(df10.iloc[:f//10,2],shade=True,color='r',linewidth=0.7,label='外圈')

# plt.savefig('C:\\Users\\shamrockyj\\Desktop\\多工况对比.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# ### 行星齿轮箱一级太阳轮

# %%
filename1 = "C:/Users/shamrockyj/Desktop/DDS数据/20T/34_22_chip_20T_1_22-03-03_0910.tdms"
tf1 = td.read(filename1)
filename2 = "C:/Users/shamrockyj/Desktop/DDS数据/20T/34_22_miss_20T_1_22-02-28_0948.tdms"
tf2 = td.read(filename2)
filename3 = "C:/Users/shamrockyj/Desktop/DDS数据/20T/34_22_pit_20T_1_22-03-04_1436.tdms"
tf3 = td.read(filename3)
filename4 = "C:/Users/shamrockyj/Desktop/DDS数据/20T/34_22_worn_20T_1_22-03-03_1618.tdms"
tf4 = td.read(filename4)
filename5 = "C:/Users/shamrockyj/Desktop/DDS数据/40T/34_22_normal_pl_1_22-03-10_1505.tdms"
tf5 = td.read(filename5)

# %%
f = 51200

# %%
df1 = tf1.as_dataframe()
df2 = tf2.as_dataframe()
df3 = tf3.as_dataframe()
df4 = tf4.as_dataframe()
df5 = tf5.as_dataframe()

# %%
plt.figure(figsize=(12,6))
plt.subplot(5,1,1)
plt.plot(df1.iloc[:f//10,1],label = '断齿',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(5,1,2)
plt.plot(df2.iloc[:f//10,1],label = '缺齿',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(5,1,3)
plt.plot(df3.iloc[:f//10,1],label = '点蚀',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(5,1,4)
plt.plot(df4.iloc[:f//10,1],label = '磨损',linewidth=1)
plt.legend(loc = 'upper right')
plt.subplot(5,1,5)
plt.plot(df5.iloc[:f//10,1],label = '正常',linewidth=1)
plt.legend(loc = 'upper right')

# %% [markdown]
# ### 行星齿轮箱一级太阳轮不同转动频率下信号差异

# %%
filenameS1 = "C:/Users/shamrockyj/Desktop/DDS数据/20T/34_22_miss_20T_1_22-02-28_0948.tdms"
tdms_file1 = td.read(filenameS1)
filenameS2 = "C:/Users/shamrockyj/Desktop/DDS数据/20T/57_22_miss_20T_1_22-02-28_1103.tdms"
tdms_file2 = td.read(filenameS2)

# %%
tdms_file_df1 = tdms_file1.as_dataframe()
tdms_file_df2 = tdms_file2.as_dataframe()

# %%
N = (57/34)**2

# %%
plt.figure(figsize=(20,6))
plt.subplot(6,1,1)
plt.plot(tdms_file_df1.iloc[:f,1])
plt.subplot(6,1,2)
plt.plot(tdms_file_df1.iloc[:f,2])
plt.subplot(6,1,3)
plt.plot(tdms_file_df1.iloc[:f,3])
plt.subplot(6,1,4)
plt.plot(tdms_file_df1.iloc[:f,4])
plt.subplot(6,1,5)
plt.plot(tdms_file_df1.iloc[:f,5])
plt.subplot(6,1,6)
plt.plot(tdms_file_df1.iloc[:f,6])

# %% [markdown]
# #### 电机转频

# %%
plt.figure(figsize=(20,3))
plt.plot(tdms_file_df1.iloc[:f,0])

# %%
plt.figure(figsize=(20,3))
plt.plot(tdms_file_df2.iloc[:f,0])

# %% [markdown]
# #### 振动加速度的观察

# %% [markdown]
# #### 通道0 行星齿轮箱小端盖 NI-2—轴向

# %%
plt.figure(figsize=(20,3))
plt.subplot(2,1,1)
plt.plot(tdms_file_df1.iloc[:f,1])
plt.subplot(2,1,2)
plt.plot(tdms_file_df2.iloc[:f,1])

# %% [markdown]
# #### 通道1 行星齿轮箱小端盖 NI-3—水平径向

# %%
plt.figure(figsize=(20,3))
plt.subplot(2,1,1)
plt.plot(tdms_file_df1.iloc[:f,2])
plt.subplot(2,1,2)
plt.plot(tdms_file_df2.iloc[:f,2])

# %% [markdown]
# #### 通道2 行星齿轮箱小端盖 NI-4—垂直径向

# %%
plt.figure(figsize=(20,3))
plt.subplot(2,1,1)
plt.plot(tdms_file_df1.iloc[:f,3])
plt.subplot(2,1,2)
plt.plot(tdms_file_df2.iloc[:f,3])

# %% [markdown]
# #### 通道3 行星齿轮箱右侧箱体

# %%
plt.figure(figsize=(20,3))
plt.subplot(2,1,1)
plt.plot(tdms_file_df1.iloc[:f,4])
plt.subplot(2,1,2)
plt.plot(tdms_file_df2.iloc[:f,4])

# %% [markdown]
# #### 通道4 承重台面-靠平行齿轮箱

# %%
plt.figure(figsize=(20,3))
plt.subplot(2,1,1)
plt.plot(tdms_file_df1.iloc[:f,5])
plt.subplot(2,1,2)
plt.plot(tdms_file_df2.iloc[:f,5])

# %% [markdown]
# #### 通道5 承重台面-靠电机

# %%
plt.figure(figsize=(20,3))
plt.subplot(2,1,1)
plt.plot(tdms_file_df1.iloc[:f,6])
plt.subplot(2,1,2)
plt.plot(tdms_file_df2.iloc[:f,6])
